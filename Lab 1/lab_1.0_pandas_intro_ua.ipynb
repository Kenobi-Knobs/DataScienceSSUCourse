# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenobi-Knobs/DataScienceSSUCourse/blob/master/Lab%201/lab_1.0_pandas_intro_ua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Лабораторна робота № 0.<br> Використання основних функцій бібліотеки Pandas</center>

# %%
import numpy as np
import pandas as pd

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# **Доступ до даних на google drive**, якщо ви відкриваєте блокнот в **google colab**, а не на PC, можна отримати шляхом монтування google drive

# %%
# шлях до папки з даними на моєму github, відредагуйте згідно вашого випадку
data_folder = "https://raw.githubusercontent.com/Kenobi-Knobs/DataScienceSSUCourse/master/Lab%201/data"

# %% [markdown]
# **Зчитуємо дані з файлу**

# %%
#data = pd.read_csv('data/beauty.csv', sep=';')

data = pd.read_csv(data_folder+'/beauty.csv', sep=';')
data.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Дивимося на перші 5 рядків**

# %%
data.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
data.shape
# Out:
# (1260, 10)

# %% [markdown]
# **Коротка статистика – info і describe**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wage      1260 non-null   float64
#  1   exper     1260 non-null   int64
#  2   union     1260 non-null   int64
#  3   goodhlth  1260 non-null   int64
#  4   black     1260 non-null   int64
#  5   female    1260 non-null   int64
#  6   married   1260 non-null   int64
#  7   service   1260 non-null   int64
#  8   educ      1260 non-null   int64
#  9   looks     1260 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 98.6 KB

# %%
data.describe()
# Out:
#               wage        exper        union     goodhlth        black  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      6.306690    18.206349     0.272222     0.933333     0.073810
# std       4.660639    11.963485     0.445280     0.249543     0.261564
# min       1.020000     0.000000     0.000000     0.000000     0.000000
# 25%       3.707500     8.000000     0.000000     1.000000     0.000000
# 50%       5.300000    15.000000     0.000000     1.000000     0.000000
# 75%       7.695000    27.000000     1.000000     1.000000     0.000000
# max      77.720000    48.000000     1.000000     1.000000     1.000000
#
#             female      married      service         educ        looks
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      0.346032     0.691270     0.273810    12.563492     3.185714
# std       0.475892     0.462153     0.446089     2.624489     0.684877
# ...

# %% [markdown]
# **Индексация**

# %%
data['exper'].head()
# Out:
# 0    30
# 1    28
# 2    35
# 3    38
# 4    27
# Name: exper, dtype: int64

# %% [markdown]
# **loc та iloc**

# %%
data.loc[0:5, ['wage', 'female']]
# Out:
#     wage  female
# 0   5.73       1
# 1   4.28       1
# 2   7.96       1
# 3  11.57       0
# 4  11.42       0
# 5   3.91       1

# %%
data.iloc[:,2:4].head()
# Out:
#    union  goodhlth
# 0      0         1
# 1      0         1
# 2      0         1
# 3      0         1
# 4      0         1

# %% [markdown]
# **Логічна індексація**

# %%
data[data['female'] == 1]['wage'].mean(), \
data[data['female'] == 0]['wage'].mean()
# Out:
# (4.299357798165137, 7.3688228155339806)

# %%
data[(data['female'] == 0) & (data['married'] == 1)]['wage'].median(), \
data[(data['female'] == 0) & (data['married'] == 0)]['wage'].median()
# Out:
# (6.710000000000001, 5.0649999999999995)

# %% [markdown]
# **Groupby**

# %%
for look, sub_df in data.groupby('looks'):
    print(look)
    
    # що загодно
    print(sub_df['goodhlth'].mean())
# Out:
# 1
# 0.8461538461538461
# 2
# 0.9366197183098591
# 3
# 0.9210526315789473
# 4
# 0.9560439560439561
# 5
# 1.0

# %%
data.groupby('looks')[['wage', 'exper']].agg(np.median)
# Out:
#         wage  exper
# looks
# 1      3.460   32.0
# 2      4.595   18.0
# 3      5.635   18.0
# 4      5.240   12.5
# 5      4.810    8.0

# %% [markdown]
# **Сводная таблица**

# %%
pd.crosstab(data['female'], data['married'])
# Out:
# married    0    1
# female
# 0        166  658
# 1        223  213

# %%
pd.crosstab(data['female'], data['looks'])
# Out:
# looks   1   2    3    4   5
# female
# 0       8  88  489  228  11
# 1       5  54  233  136   8

# %% [markdown]
# **Добавление столбцов (построение признаков)**

# %%
data['is_rich'] = (data['wage'] > 
                   data['wage'].quantile(.75)).astype('int64')

# %%
data.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0   5.73     30      0         1      0       1        1        1    14
# 1   4.28     28      0         1      0       1        1        0    12
# 2   7.96     35      0         1      0       1        0        0    10
# 3  11.57     38      0         1      0       0        1        1    16
# 4  11.42     27      0         1      0       0        1        0    16
#
#    looks  is_rich
# 0      4        0
# 1      3        0
# 2      4        1
# 3      3        1
# 4      3        1

# %%
data['rubbish'] = .56 * data['wage'] + 0.32 * data['exper']

# %% [markdown]
# **map и apply**

# %%
def string_gender(female):
    return 'female' if female else 'male'

# %%
d =  {1: 'union', 0: 'non-union'}

# %%
data['union'].map(d).head()
# Out:
# 0    non-union
# 1    non-union
# 2    non-union
# 3    non-union
# 4    non-union
# Name: union, dtype: object

# %%
data['female'].apply(lambda female: 'female' if female else 'male').head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: female, dtype: object
